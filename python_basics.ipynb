# %%
print("welcome to Data Science")
# Out:
# welcome to Data Science

# %%
x=5
print(x)
print(f"value of x is: {x}")
print (type(x))
print ("Muziiiii")
# Out:
# 5
# value of x is: 5
# <class 'int'>
# Muziiiii

# %%
x= 7
y=7

print(x-y)
print(x*y)
# Out:
# 0
# 49

# %%
username= input("Muhammad Fariz Ilhan")
print(f"Hello, {username}!")
